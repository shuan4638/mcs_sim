# %%
from collections import defaultdict
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

see = 'Mutations2'
for k in ['Tam', 'fast_MCS', 'rdkit_MCS']:
    df = pd.read_csv('outputs/%s_%s.csv' % (k, see))
    if k == 'Tam':
        baseline = np.mean(df['time'].tolist())
        print ('baseline: %.4f' % baseline)
    print (k, np.mean(df['time'].tolist())/baseline)
    plt.hist([np.log2(t) for t in df['time'].tolist()], label=k, alpha=0.3)

plt.legend()
plt.show()
# Out:
# baseline: 0.0002
# Tam 1.0
# fast_MCS 1.9773861109601736
# rdkit_MCS 60036.72483988964

# %%
for k in ['Tam', 'fast_MCS', 'rdkit_MCS']:
    df = pd.read_csv('outputs/%s_%s.csv' % (k, see))
#     scores = [min([s[1], 1]) for ss in df['similar_mols'] for s in eval(ss)]
    scores = [s[1] for ss in df['similar_mols'] for s in eval(ss)]

    plt.hist(scores, label=k, alpha=0.3)

plt.legend()
plt.show()

# %%
sim_mols = {}
for k in ['Tam', 'rdkit_MCS', 'fast_MCS', 'hybrid']:
    df = pd.read_csv('outputs/%s_%s.csv' % (k, see))
    smiles = df['smiles'].tolist()
    mols = {}
    for i, ss in enumerate(df['similar_mols']):
        mols[i] = eval(ss)
    sim_mols[k] = mols

# %%
large_diff = []
pos_diff = []
for i in range(len(smiles)):
    diff = abs(sim_mols['Tam'][i][0][1]-sim_mols['fast_MCS'][i][0][1])
    if diff > 0.3:
        print ('L', i, sim_mols['Tam'][i][0][1]-sim_mols['fast_MCS'][i][0][1])
        large_diff.append(i)
    if sim_mols['Tam'][i][0][1]-sim_mols['fast_MCS'][i][0][1]>0:
        print ('P', i, sim_mols['Tam'][i][0][1]-sim_mols['fast_MCS'][i][0][1])
        pos_diff.append(i)
# Out:
# P 1 0.016079158936301796
# P 4 0.08882783882783873
# L 10 -0.31410256410256404
# L 17 -0.32751937984496127
# L 29 -0.5434782608695652
# L 54 -0.3063063063063064
# P 66 0.028869286287089013
# L 95 -0.3942857142857143
# P 105 0.19987349778621133
# L 112 -0.35477941176470584
# L 114 -0.3704545454545454
# L 117 -0.3098471986417657
# L 128 -0.3098471986417657
# L 136 -0.3070175438596492
# P 138 0.02631578947368418
# L 160 -0.3699059561128527
# L 164 -0.4696969696969697
# L 165 -0.326530612244898
# L 172 -0.3120204603580563
# L 178 -0.36246672582076306
# P 187 0.06676342525399126
# L 192 -0.3848684210526315
# L 198 -0.45345622119815676

# %%
from rdkit import Chem
# 140, 20, 198, 95, 10

i = 10
sims = {}
display_mols = [smiles[i], 'H', 'H']
for k, v in sim_mols.items():
    display_mols += [vv[0] for vv in v[i]]
    print (k, [vv[1] for vv in v[i]])
    
print (sim_mols['rdkit_MCS'][i])
print (smiles[i])
Chem.Draw.MolsToGridImage([Chem.MolFromSmiles(smi) for smi in display_mols])
# Out:
# Tam [0.4807692307692308, 0.47368421052631576, 0.423728813559322]
# rdkit_MCS [0.8205128205128205, 0.8048780487804879, 0.7804878048780488]
# fast_MCS [0.7948717948717948, 0.775, 0.7560975609756098]
# hybrid [0.6181827410892919, 0.6058921217163123, 0.566021485853048]
# [('CC(C)(C)NC(=O)c1cc(-c2cc(F)cc(C(F)(F)F)c2)cc(-c2cc(C(F)(F)F)cc(C(F)(F)F)c2)c1', 0.8205128205128205), ('COc1ccc(C=C(C)c2cc(-c3cc(F)cc(C(F)(F)F)c3)cc(-c3cc(C(F)(F)F)cc(C(F)(F)F)c3)c2)cc1', 0.8048780487804879), ('CC(C)(C)NC(=S)NNC(=O)c1cc(-c2cc(F)cc(C(F)(F)F)c2)cc(-c2cc(C(F)(F)F)cc(C(F)(F)F)c2)c1', 0.7804878048780488)]
# COC(=O)C(CC(C)C)c1cc(-c2cc(F)cc(C(F)(F)F)c2)cc(-c2cc(C(F)(F)F)cc(C(F)(F)F)c2)c1

# %%
see = 'Sims'
baseline = 0
for k in ['Tam', 'fast_MCS', 'rdkit_MCS', 'hybrid']:
    df = pd.read_csv('outputs/%s_%s.csv' % (k, see))
    if k == 'Tam':
        baseline = np.mean(df['time'].tolist())
        print ('baseline: %.4f' % baseline)
    print (k, np.mean(df['time'].tolist())/baseline)
    plt.hist([np.log2(t) for t in df['time'].tolist()], label=k, alpha=0.3)

plt.legend()
plt.show()
# Out:
# baseline: 0.0001
# Tam 1.0
# fast_MCS 2.4291429808904716
# rdkit_MCS 57.52641612479327
# hybrid 3.429142980890801

# %%
for k in ['Tam', 'rdkit_MCS', 'fast_MCS', 'hybrid']:
    df = pd.read_csv('outputs/%s_%s.csv' % (k, see))
    scores = [min([s[1], 1]) for ss in df['similar_mols'] for s in eval(ss)]
    plt.hist(scores, label=k, alpha=0.3)

plt.legend()
plt.show()

# %%
sim_mols = {}
for k in ['Tam', 'rdkit_MCS', 'fast_MCS', 'hybrid']:
    df = pd.read_csv('outputs/%s_%s.csv' % (k, see))
    smiles = df['smiles'].tolist()
    mols = {}
    for i, ss in enumerate(df['similar_mols']):
        mols[i] = eval(ss)
    sim_mols[k] = mols

# %%
large_diff = []
pos_diff = []
for i in range(len(smiles)):
    diff = abs(sim_mols['Tam'][i][0][1]-sim_mols['fast_MCS'][i][0][1])
    if diff > 0.3:
        print ('L', i, sim_mols['Tam'][i][0][1]-sim_mols['fast_MCS'][i][0][1])
        large_diff.append(i)
    if sim_mols['Tam'][i][0][1]-sim_mols['fast_MCS'][i][0][1]>0:
        print ('P', i, sim_mols['Tam'][i][0][1]-sim_mols['fast_MCS'][i][0][1])
        pos_diff.append(i)
# large_diff
# Out:
# L 13 -0.33333333333333337
# L 24 -0.4296296296296296
# L 28 -0.42337662337662335
# L 32 -0.3014184397163121
# L 43 -0.359090909090909
# L 61 -0.31868131868131866
# P 80 0.030745967741935498
# P 82 0.04948601482189818
# L 84 -0.4053751399776036
# L 94 -0.35389610389610393
# P 101 0.033333333333333326
# L 109 -0.32571032571032565
# P 112 0.014634146341463372
# L 127 -0.30878969167050163
# L 140 -0.31657914478619653
# P 145 0.09392789373814048
# L 162 -0.3666666666666667
# L 165 -0.30000000000000004
# L 169 -0.3022727272727273
# L 172 -0.3636363636363637
# L 174 -0.41666666666666663

# %%
from rdkit import Chem
i = 172
sims = {}
display_mols = [smiles[i], 'H', 'H']
for k, v in sim_mols.items():
    display_mols += [vv[0] for vv in v[i]]
    sims[k] = [vv[1] for vv in v[i]]
    
print (sim_mols['rdkit_MCS'][i])
print (smiles[i])
print (sims)
Chem.Draw.MolsToGridImage([Chem.MolFromSmiles(smi) for smi in display_mols])
# Out:
# [('Cn1cnc(-c2cc(C#N)ccn2)c1-c1ccc(-n2cccn2)cc1', 0.9090909090909091), ('CCN(CC)Cc1ccc(-c2nc(C)c(COc3ccc([C@H](CC(=O)N4C(=O)OC[C@@H]4Cc4ccccc4)c4ccon4)cc3)s2)cc1', 0.8333333333333334), ('COC(=O)[C@H](CCCCN)NC(=O)Nc1cc(OC)cc(C(C)(C)C)c1O', 0.8181818181818182)]
# CSc1cc(C=O)ccc1C
# {'Tam': [0.45454545454545453, 0.4444444444444444, 0.4444444444444444], 'rdkit_MCS': [0.9090909090909091, 0.8333333333333334, 0.8181818181818182], 'fast_MCS': [0.8181818181818182, 0.8, 0.782608695652174], 'hybrid': [0.6098367211363063, 0.5773502691896257, 0.5669467095138409]}

# %%
'COC(=O)[C@H](CCCCN)NC(=O)Nc1cc(OC)cc(C(C)(C)C)c1O' in smiles
# Out:
# False
